# %% [markdown]
# #cars Recognizer
# The goal of this project is to classify the logos of 20 different car brands from around the world. The types are following: <br/>
#
# * Audi car logo
# * BMW car logo
# * Chevrolet car logo
# * Dodge car logo
# * Ford car logo
# * Honda car logo
# * Hyundai car logo
# * Jaguar car logo
# * Jeep car logo
# * Kia car logo
# * Land Rover car logo
# * Lexus car logo
# * Mazda car logo
# * Mercedes-Benz car logo
# * Nissan car logo
# * Porsche car logo
# * Subaru car logo
# * Tesla car logo
# * Toyota car logo
# * Volkswagen car logo

# %% [markdown]
# ##Setting up for inference

# %%
# !pip install -Uqq fastai

# %%
from fastai.vision.all import *

# %% [markdown]
# #mount the drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/My Drive/MasterCourseML/week-8/logo classification
# Out:
# /content/drive/My Drive/MasterCourseML/week-8/logo classification

# %%
version = 0
image_path = 'test_images'
model_path = f"models/logo_recognizer_v{version}.pkl"

# %%
model = load_learner(model_path)

# %% [markdown]
# ###Inference 1
# target: cowboy hat

# %%
img = Image.open(f"{image_path}/Mazda-Logo.png")
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=P size=128x72>

# %%
model.predict(img)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Mazda car logo',
#  tensor(12),
#  tensor([5.4799e-06, 3.1965e-06, 1.2041e-05, 4.6861e-05, 1.0610e-07, 8.5583e-07, 5.0160e-07, 3.3856e-07, 1.4710e-05, 6.3070e-08, 3.6923e-08, 4.9773e-07, 9.9976e-01, 2.4543e-06, 4.5835e-06, 1.6498e-05,
#          2.5772e-08, 6.0597e-05, 1.7081e-06, 7.3447e-05]))

# %% [markdown]
# ###Inference 2
# target: beanie cap

# %%
img_b = Image.open(f"{image_path}/toyota-logo.png")
img_b.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x104>

# %%
model.predict(img_b)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Toyota car logo',
#  tensor(18),
#  tensor([3.4936e-06, 8.9483e-07, 1.9184e-06, 3.7515e-05, 2.3190e-05, 3.2064e-05, 1.0401e-06, 2.0148e-06, 2.7478e-06, 2.4724e-05, 6.6865e-07, 2.8310e-05, 2.5768e-06, 2.0353e-06, 4.2662e-05, 3.5683e-07,
#          4.0771e-07, 2.4809e-06, 9.9977e-01, 1.7021e-05]))

# %% [markdown]
# ###Inference 3
# target: taqiyah cap

# %%
img_t = Image.open(f"{image_path}/marcedes.png")
img_t.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=P size=128x113>

# %%
model.predict(img_t)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Mercedes-Benz car logo',
#  tensor(13),
#  tensor([0.1020, 0.0187, 0.0008, 0.0094, 0.0032, 0.0095, 0.0071, 0.1920, 0.0053, 0.0006, 0.0532, 0.0112, 0.0179, 0.5185, 0.0019, 0.0130, 0.0069, 0.0184, 0.0034, 0.0068]))

# %% [markdown]
# ###Inference 4
# target: boater hat

# %%
img_bt = Image.open(f"{image_path}/Mazda-Logo.png")
img_bt.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=P size=128x72>

# %%
model.predict(img_bt)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Mazda car logo',
#  tensor(12),
#  tensor([5.4799e-06, 3.1965e-06, 1.2041e-05, 4.6861e-05, 1.0610e-07, 8.5583e-07, 5.0160e-07, 3.3856e-07, 1.4710e-05, 6.3070e-08, 3.6923e-08, 4.9773e-07, 9.9976e-01, 2.4543e-06, 4.5835e-06, 1.6498e-05,
#          2.5772e-08, 6.0597e-05, 1.7081e-06, 7.3447e-05]))
